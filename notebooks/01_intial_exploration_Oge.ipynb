# %% [markdown]
# Starting with the main `tumour.csv` table (Other datasets may be joined as we progress)

# %% [markdown]
# Initial exploration to understand the data strucure of the main `tumour.csv` table

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd

# Loading into a pandas DataFrame and displaying the first few rows
df = pd.read_csv('/content/drive/MyDrive/simulacrum_v2.1.0\Data\sim_av_tumour.csv')
display(df.head())
# Out:
# /tmp/ipython-input-4-714782997.py:4: DtypeWarning: Columns (14,15,16,17,23,24,25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('sim_av_tumour.csv')
#    TUMOURID  GENDER  PATIENTID DIAGNOSISDATEBEST SITE_ICD10_O2_3CHAR  \
# 0  10399610       1   10000001        2017-03-31                 C44
# 1  10694862       1   10000002        2016-01-14                 C44
# 2  11938715       2   10000003        2018-12-10                 C44
# 3  11869010       1   10000004        2018-04-05                 C44
# 4  11037077       1   10000005        2018-04-23                 C44
#
#   SITE_ICD10_O2 SITE_ICD10R4_O2_3CHAR_FROM2013 SITE_ICD10R4_O2_FROM2013  \
# 0          C444                            C44                     C444
# 1          C449                            C44                     C449
# 2          C442                            C44                     C442
# ...

# %%
# Display column names and their data types
print("Column names and data types:")
display(df.info())

# Display the number of rows and columns
print("\nShape of the DataFrame (rows, columns):")
display(df.shape)
# Out:
# Column names and data types:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1995570 entries, 0 to 1995569
# Data columns (total 37 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   TUMOURID                        int64
#  1   GENDER                          int64
#  2   PATIENTID                       int64
#  3   DIAGNOSISDATEBEST               object
#  4   SITE_ICD10_O2_3CHAR             object
#  5   SITE_ICD10_O2                   object
#  6   SITE_ICD10R4_O2_3CHAR_FROM2013  object
#  7   SITE_ICD10R4_O2_FROM2013        object
#  8   SITE_ICDO3REV2011               object
#  9   SITE_ICDO3REV2011_3CHAR         object
#  10  MORPH_ICD10_O2                  int64
#  11  MORPH_ICDO3REV2011              float64
#  12  BEHAVIOUR_ICD10_O2              int64
#  13  BEHAVIOUR_ICDO3REV2011          int64
#  14  T_BEST                          object
#  15  N_BEST                          object
# ...

# %%
# Filter the DataFrame for prostate cancer patients (SITE_ICD10R4_O2_3CHAR_FROM2013 == 'C61')
prostate_df = df[df['SITE_ICD10R4_O2_3CHAR_FROM2013'] == 'C61']

# Display the first few rows of the filtered DataFrame
display(prostate_df.head())

# Display the number of rows in the filtered DataFrame
print(f"\nNumber of prostate cancer patients (C61): {len(prostate_df)}")
# Out:
#         TUMOURID  GENDER  PATIENTID DIAGNOSISDATEBEST SITE_ICD10_O2_3CHAR  \
# 496942  11233091       1   10204272        2018-07-23                 C61
# 496943  11956218       1   10204300        2018-08-09                 C61
# 496944  10341168       2   10204313        2019-01-05                 C61
# 496945  11881098       2   10204322        2018-09-21                 C61
# 496946  11020725       1   10204325        2019-11-27                 C61
#
#        SITE_ICD10_O2 SITE_ICD10R4_O2_3CHAR_FROM2013 SITE_ICD10R4_O2_FROM2013  \
# 496942           C61                            C61                      C61
# 496943           C61                            C61                      C61
# 496944           C61                            C61                      C61
# 496945           C61                            C61                      C61
# 496946           C61                            C61                      C61
#
# ...

# %%
# Provide summary statistics for numerical columns
print("\nSummary statistics for numerical columns:")
display(prostate_df.describe())

# Check for missing values in each column
print("\nMissing values per column:")
display(prostate_df.isnull().sum())
# Out:
# Summary statistics for numerical columns:
#            TUMOURID         GENDER     PATIENTID  MORPH_ICD10_O2  \
# count  1.794780e+05  179478.000000  1.794780e+05   179478.000000
# mean   1.099946e+07       1.014631  3.099301e+07     8126.248097
# std    5.765975e+05       0.120072  1.062636e+07       70.489359
# min    1.000002e+07       1.000000  1.013342e+07     8000.000000
# 25%    1.050121e+07       1.000000  3.004136e+07     8140.000000
# 50%    1.099973e+07       1.000000  3.008623e+07     8140.000000
# 75%    1.149678e+07       1.000000  3.013110e+07     8140.000000
# max    1.200000e+07       2.000000  2.500025e+08     9989.000000
#
#        MORPH_ICDO3REV2011  BEHAVIOUR_ICD10_O2  BEHAVIOUR_ICDO3REV2011  \
# count       179478.000000       179478.000000           179478.000000
# mean          8126.334403            2.999682                2.999866
# std             70.216668            0.045342                0.040197
# ...

# %% [markdown]
# Next steps may include
#
# - **Understand more of the data:** Read up and get some basic info on these 37 ttributes to safely determine any interesting correlations. It may make sense to share it amongst ourselves and hold a team briefing to share our findings.
#
# - **Univariate analysis:** Analyze the distribution of individual variables (e.g., AGE, GENDER, PERFORMANCESTATUS, GLEASON_COMBINED) using visualizations like histograms, bar plots, and box plots.
#
# - **Bivariate analysis:** Explore relationships between pairs of variables (e.g., AGE vs. PERFORMANCESTATUS, GLEASON_COMBINED vs. STAGE_BEST) using scatter plots, box plots, or other appropriate visualizations.
#
# - **Handle missing values:** Decide on a strategy for handling missing values based on the analysis in the previous steps (e.g., imputation, removal).
# Identify outliers: Detect and handle outliers in numerical variables if necessary.
#
# - **Summarize findings:** Document the key insights and observations from the EDA.
#
# - **Finish task:** Conclude the EDA process and prepare for further analysis or modeling.
